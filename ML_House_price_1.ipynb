# %% [markdown]
# <a href="https://colab.research.google.com/github/Rachitha2908/MachineLearning2023/blob/main/ML_House_price_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot as plt

# The following lines adjust the granularity of reporting. 
pd.options.display.max_rows = 10
pd.options.display.float_format = "{:.1f}".format

# %%
# Import the dataset.
training_df = pd.read_csv('/content/california_housing_train (1).csv')


# Print the first rows of the pandas DataFrame.
training_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0            1.5             66900.0
# 1      1129.0       463.0            1.8             80100.0
# 2       333.0       117.0            1.7             85700.0
# 3       515.0       226.0            3.2             73400.0
# 4       624.0       262.0            1.9             65500.0

# %%
#check for presence of None in any column of the dataframe
print(training_df.isnull().values.any())

#provides sum of NA from each column
training_df.isna().sum()
# Out:
# False
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
# dropna(inplace = True) will remove all rows containing NULL values from the original DataFrame.
training_df.dropna(inplace = True)

# %%
#To discover duplicates, we can use the duplicated() method. The duplicated() method returns a Boolean values for each row.
print(training_df.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16995    False
# 16996    False
# 16997    False
# 16998    False
# 16999    False
# Length: 17000, dtype: bool

# %%
#Remove all duplicates: The (inplace = True) will make sure that the method does NOT return a new DataFrame, but it will remove all duplicates from the original DataFrame.
training_df.drop_duplicates(inplace = True)

# %%
#check for presence of None in any column of the dataframe
print(training_df.isnull().values.any())

#provides sum of NA from each column
training_df.isna().sum()
# Out:
# False
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
#To discover duplicates, we can use the duplicated() method. The duplicated() method returns a Boolean values for each row.
print(training_df.duplicated())
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16995    False
# 16996    False
# 16997    False
# 16998    False
# 16999    False
# Length: 17000, dtype: bool

# %%
# Print the first rows of the pandas DataFrame.
training_df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -114.3      34.2                15.0       5612.0          1283.0
# 1     -114.5      34.4                19.0       7650.0          1901.0
# 2     -114.6      33.7                17.0        720.0           174.0
# 3     -114.6      33.6                14.0       1501.0           337.0
# 4     -114.6      33.6                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0            1.5             66900.0
# 1      1129.0       463.0            1.8             80100.0
# 2       333.0       117.0            1.7             85700.0
# 3       515.0       226.0            3.2             73400.0
# 4       624.0       262.0            1.9             65500.0

# %%
training_df.corr()
# Out:
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude                 1.0      -0.9                -0.1          0.0
# latitude                 -0.9       1.0                 0.0         -0.0
# housing_median_age       -0.1       0.0                 1.0         -0.4
# total_rooms               0.0      -0.0                -0.4          1.0
# total_bedrooms            0.1      -0.1                -0.3          0.9
# population                0.1      -0.1                -0.3          0.9
# households                0.1      -0.1                -0.3          0.9
# median_income            -0.0      -0.1                -0.1          0.2
# median_house_value       -0.0      -0.1                 0.1          0.1
#
#                     total_bedrooms  population  households  median_income  \
# longitude                      0.1         0.1         0.1           -0.0
# latitude                      -0.1        -0.1        -0.1           -0.1
# housing_median_age            -0.3        -0.3        -0.3           -0.1
# total_rooms                    0.9         0.9         0.9            0.2
# total_bedrooms                 1.0         0.9         1.0           -0.0
# population                     0.9         1.0         0.9           -0.0
# households                     1.0         0.9         1.0            0.0
# median_income                 -0.0        -0.0         0.0            1.0
# median_house_value             0.0        -0.0         0.1            0.7
#
#                     median_house_value
# longitude                         -0.0
# latitude                          -0.1
# housing_median_age                 0.1
# total_rooms                        0.1
# total_bedrooms                     0.0
# population                        -0.0
# households                         0.1
# median_income                      0.7
# median_house_value                 1.0

# %%
#Delete column 'Year' as it has no correlation with other data and can't be used for training and prediction
del training_df['longitude']
del training_df['latitude']
del training_df['housing_median_age']
del training_df['total_rooms']
del training_df['total_bedrooms']
del training_df['median_income']
del training_df['households']
#del training_df['Showroom_Price']
print(training_df)
training_df.corr()
# Out:
#        population  median_house_value
# 0          1015.0             66900.0
# 1          1129.0             80100.0
# 2           333.0             85700.0
# 3           515.0             73400.0
# 4           624.0             65500.0
# ...           ...                 ...
# 16995       907.0            111400.0
# 16996      1194.0             79000.0
# 16997      1244.0            103600.0
# 16998      1298.0             85800.0
# 16999       806.0             94600.0
#
# [17000 rows x 2 columns]
#                     population  median_house_value
# population                 1.0                -0.0
# median_house_value        -0.0                 1.0

# %%
# Get statistics on the dataset.
training_df.describe()
# Out:
#        population  median_house_value
# count     17000.0             17000.0
# mean       1429.6            207300.9
# std        1147.9            115983.8
# min           3.0             14999.0
# 25%         790.0            119400.0
# 50%        1167.0            180400.0
# 75%        1721.0            265000.0
# max       35682.0            500001.0

# %%
#@title Define the functions that build and train a model
def build_model(my_learning_rate):
  """Create and compile a simple linear regression model."""
  # Most simple tf.keras models are sequential.
  model = tf.keras.models.Sequential()

  # Describe the topography of the model.
  # The topography of a simple linear regression model
  # is a single node in a single layer.
  model.add(tf.keras.layers.Dense(units=1, 
                                  input_shape=(1,)))

  # Compile the model topography into code that TensorFlow can efficiently
  # execute. Configure training to minimize the model's mean squared error. 
  model.compile(optimizer=tf.keras.optimizers.RMSprop(learning_rate=my_learning_rate),
                loss="mean_squared_error",
                metrics=[tf.keras.metrics.RootMeanSquaredError()])

  return model        


def train_model(model, df, feature, label, epochs, batch_size):
  """Train the model by feeding it data."""

  # Feed the model the feature and the label.
  # The model will train for the specified number of epochs. 
  history = model.fit(x=df[feature],
                      y=df[label],
                      batch_size=batch_size,
                      epochs=epochs)

  # Gather the trained model's weight and bias.
  trained_weight = model.get_weights()[0]
  trained_bias = model.get_weights()[1]

  # The list of epochs is stored separately from the rest of history.
  epochs = history.epoch
  
  # Isolate the error for each epoch.
  hist = pd.DataFrame(history.history)

  # To track the progression of training, we're going to take a snapshot
  # of the model's root mean squared error at each epoch. 
  rmse = hist["root_mean_squared_error"]

  return trained_weight, trained_bias, epochs, rmse

print("Defined the build_model and train_model functions.")
# Out:
# Defined the build_model and train_model functions.

# %%
#@title Define the plotting functions
def plot_the_model(trained_weight, trained_bias, feature, label):
  """Plot the trained model against 200 random training examples."""

  # Label the axes.
  plt.xlabel(feature)
  plt.ylabel(label)

  # Create a scatter plot from 100 random points of the dataset.
  random_examples = training_df.sample(n=100)
  plt.scatter(random_examples[feature], random_examples[label])

  # Create a red line representing the model. The red line starts
  # at coordinates (x0, y0) and ends at coordinates (x1, y1).
  x0 = 0
  y0 = trained_bias
  x1 = random_examples[feature].max()
  y1 = trained_bias + (trained_weight * x1)
  plt.plot([x0, x1], [y0, y1], c='r')

  # Render the scatter plot and the red line.
  plt.show()


def plot_the_loss_curve(epochs, rmse):
  """Plot a curve of loss vs. epoch."""

  plt.figure()
  plt.xlabel("Epoch")
  plt.ylabel("Root Mean Squared Error")

  plt.plot(epochs, rmse, label="Loss")
  plt.legend()
  plt.ylim([rmse.min()*0.97, rmse.max()])
  plt.show()  

print("Defined the plot_the_model and plot_the_loss_curve functions.")
# Out:
# Defined the plot_the_model and plot_the_loss_curve functions.

# %%
# The following variables are the hyperparameters.
learning_rate = 0.03
epochs = 50
batch_size = 5

# Specify the feature and the label.

#########################################################################
#First execute without below line and observe that predication doesn't match actual values 
#as Kms is a large number compared to Present_Price
#training_df['Kms']=training_df['Kms']/1000

#########################################################################

my_feature = "population"  # the total number of rooms on a specific city block.
my_label="median_house_value" # the median value of a house on a specific city block.
# That is, you're going to create a model that predicts house value based 
# solely on total_rooms.  

# Discard any pre-existing version of the model.
my_model = None

# Invoke the functions.
my_model = build_model(learning_rate)
weight, bias, epochs, rmse = train_model(my_model, training_df, 
                                         my_feature, my_label,
                                         epochs, batch_size)

print("\nThe learned weight for your model is %.4f" % weight)
print("The learned bias for your model is %.4f\n" % bias )

plot_the_model(weight, bias, my_feature, my_label)
plot_the_loss_curve(epochs, rmse)
# Out:
# Epoch 1/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 39516979200.0000 - root_mean_squared_error: 198788.7812
# Epoch 2/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 31091474432.0000 - root_mean_squared_error: 176327.7500
# Epoch 3/50
# 3400/3400 [==============================] - 3s 1ms/step - loss: 31144345600.0000 - root_mean_squared_error: 176477.6094
# Epoch 4/50
# 3400/3400 [==============================] - 3s 945us/step - loss: 31326789632.0000 - root_mean_squared_error: 176993.7500
# Epoch 5/50
# 3400/3400 [==============================] - 3s 995us/step - loss: 31317553152.0000 - root_mean_squared_error: 176967.6562
# Epoch 6/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 31312185344.0000 - root_mean_squared_error: 176952.5000
# Epoch 7/50
# 3400/3400 [==============================] - 3s 961us/step - loss: 31270561792.0000 - root_mean_squared_error: 176834.8438
# Epoch 8/50
# 3400/3400 [==============================] - 3s 980us/step - loss: 31291346944.0000 - root_mean_squared_error: 176893.6094
# Epoch 9/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 31290200064.0000 - root_mean_squared_error: 176890.3594
# Epoch 10/50
# 3400/3400 [==============================] - 3s 983us/step - loss: 31295004672.0000 - root_mean_squared_error: 176903.9375
# Epoch 11/50
# 3400/3400 [==============================] - 3s 959us/step - loss: 31231211520.0000 - root_mean_squared_error: 176723.5469
# Epoch 12/50
# 3400/3400 [==============================] - 3s 973us/step - loss: 31320774656.0000 - root_mean_squared_error: 176976.7656
# Epoch 13/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 31246266368.0000 - root_mean_squared_error: 176766.1406
# Epoch 14/50
# 3400/3400 [==============================] - 3s 966us/step - loss: 31221098496.0000 - root_mean_squared_error: 176694.9375
# Epoch 15/50
# 3400/3400 [==============================] - 3s 965us/step - loss: 31198771200.0000 - root_mean_squared_error: 176631.7344
# Epoch 16/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 31198574592.0000 - root_mean_squared_error: 176631.1875
# Epoch 17/50
# 3400/3400 [==============================] - 3s 969us/step - loss: 31185094656.0000 - root_mean_squared_error: 176593.0156
# Epoch 18/50
# 3400/3400 [==============================] - 3s 958us/step - loss: 31182870528.0000 - root_mean_squared_error: 176586.7188
# Epoch 19/50
# 3400/3400 [==============================] - 3s 969us/step - loss: 31139186688.0000 - root_mean_squared_error: 176462.9844
# Epoch 20/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 31136159744.0000 - root_mean_squared_error: 176454.4062
# Epoch 21/50
# 3400/3400 [==============================] - 3s 993us/step - loss: 31223654400.0000 - root_mean_squared_error: 176702.1562
# Epoch 22/50
# 3400/3400 [==============================] - 3s 969us/step - loss: 31145981952.0000 - root_mean_squared_error: 176482.2500
# Epoch 23/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 31144837120.0000 - root_mean_squared_error: 176479.0000
# Epoch 24/50
# 3400/3400 [==============================] - 3s 977us/step - loss: 31084875776.0000 - root_mean_squared_error: 176309.0312
# Epoch 25/50
# 3400/3400 [==============================] - 3s 979us/step - loss: 31102488576.0000 - root_mean_squared_error: 176358.9688
# Epoch 26/50
# 3400/3400 [==============================] - 3s 1ms/step - loss: 31025846272.0000 - root_mean_squared_error: 176141.5469
# Epoch 27/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 31042643968.0000 - root_mean_squared_error: 176189.2344
# Epoch 28/50
# 3400/3400 [==============================] - 3s 963us/step - loss: 31069704192.0000 - root_mean_squared_error: 176266.0000
# Epoch 29/50
# 3400/3400 [==============================] - 3s 973us/step - loss: 31051761664.0000 - root_mean_squared_error: 176215.0938
# Epoch 30/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 31036033024.0000 - root_mean_squared_error: 176170.4844
# Epoch 31/50
# 3400/3400 [==============================] - 3s 968us/step - loss: 31027130368.0000 - root_mean_squared_error: 176145.2031
# Epoch 32/50
# 3400/3400 [==============================] - 3s 972us/step - loss: 31051589632.0000 - root_mean_squared_error: 176214.6094
# Epoch 33/50
# 3400/3400 [==============================] - 3s 1ms/step - loss: 30975062016.0000 - root_mean_squared_error: 175997.3281
# Epoch 34/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 30979987456.0000 - root_mean_squared_error: 176011.3281
# Epoch 35/50
# 3400/3400 [==============================] - 3s 978us/step - loss: 31058931712.0000 - root_mean_squared_error: 176235.4375
# Epoch 36/50
# 3400/3400 [==============================] - 3s 998us/step - loss: 31009081344.0000 - root_mean_squared_error: 176093.9688
# Epoch 37/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 30938005504.0000 - root_mean_squared_error: 175892.0312
# Epoch 38/50
# 3400/3400 [==============================] - 3s 970us/step - loss: 30954356736.0000 - root_mean_squared_error: 175938.5000
# Epoch 39/50
# 3400/3400 [==============================] - 3s 973us/step - loss: 30912276480.0000 - root_mean_squared_error: 175818.8750
# Epoch 40/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 30957539328.0000 - root_mean_squared_error: 175947.5469
# Epoch 41/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 30955988992.0000 - root_mean_squared_error: 175943.1406
# Epoch 42/50
# 3400/3400 [==============================] - 3s 981us/step - loss: 30914560000.0000 - root_mean_squared_error: 175825.3750
# Epoch 43/50
# 3400/3400 [==============================] - 3s 984us/step - loss: 30876499968.0000 - root_mean_squared_error: 175717.1094
# Epoch 44/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 30866841600.0000 - root_mean_squared_error: 175689.6250
# Epoch 45/50
# 3400/3400 [==============================] - 3s 955us/step - loss: 30841372672.0000 - root_mean_squared_error: 175617.1250
# Epoch 46/50
# 3400/3400 [==============================] - 3s 948us/step - loss: 30851729408.0000 - root_mean_squared_error: 175646.6094
# Epoch 47/50
# 3400/3400 [==============================] - 4s 1ms/step - loss: 30839603200.0000 - root_mean_squared_error: 175612.0781
# Epoch 48/50
# 3400/3400 [==============================] - 3s 962us/step - loss: 30848452608.0000 - root_mean_squared_error: 175637.2812
# Epoch 49/50
# 3400/3400 [==============================] - 3s 978us/step - loss: 30841972736.0000 - root_mean_squared_error: 175618.8281
# Epoch 50/50
# 3400/3400 [==============================] - 3s 948us/step - loss: 30816868352.0000 - root_mean_squared_error: 175547.3438
#
# The learned weight for your model is 97.3564
# The learned bias for your model is 3426.5107
# /usr/local/lib/python3.8/dist-packages/numpy/core/shape_base.py:65: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   ary = asanyarray(ary)

# %%
plt.plot(training_df['population'],training_df['median_house_value'])

# %%
def predict_car_values(n, feature, label):
  """Predict car values based on a feature."""

  batch = training_df[feature][100:100 + n]
  predicted_values = my_model.predict_on_batch(x=batch)

  print("feature      label          predicted")
  print("  population   median_house_value        prid median_house_value ")
  print("--------------------------------------")
  for i in range(n):
    print ("%5.2f %6.2f %15.2f" % (training_df[feature][100 + i],
                                   training_df[label][100 + i],
                                   predicted_values[i][0] ))

# %%
predict_car_values(5, my_feature, my_label)
# Out:
# feature      label          predicted
#   population   median_house_value        prid median_house_value
# --------------------------------------
# 1000.00 159900.00       100782.90
# 649.00 94400.00        66610.80
# 390.00 72500.00        41395.50
# 1005.00 83200.00       101269.68
# 766.00 62000.00        78001.51
